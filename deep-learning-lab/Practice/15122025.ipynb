# %%
# import tensorflow
import tensorflow as tf

# %%
x = tf.ones(shape=(2, 1))
print(x)
# Out:
# tf.Tensor(
# [[1.]
#  [1.]], shape=(2, 1), dtype=float32)

# %%
x = tf.zeros(shape=(2, 1))
print(x)
# Out:
# tf.Tensor(
# [[0.]
#  [0.]], shape=(2, 1), dtype=float32)

# %%
x = tf.random.normal(shape=(3, 1), mean=0., stddev=1.)
print(x)
# Out:
# tf.Tensor(
# [[-0.34774187]
#  [-0.4338793 ]
#  [ 0.8925557 ]], shape=(3, 1), dtype=float32)

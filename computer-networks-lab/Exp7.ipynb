# %%
import random
import time

# Constants
TOTAL_FRAMES = 10
WINDOW_SIZE = 4
LOSS_PROBABILITY = 0.3
DELAY = 0.8  # Time delay for demonstration

# Status arrays
sender_window = [False] * TOTAL_FRAMES     # True means ACK received
receiver_window = [None] * TOTAL_FRAMES    # None means not yet received

def selective_repeat_protocol():
    base = 0
    print("=== Selective Repeat Sliding Window Protocol ===\n")
    while base < TOTAL_FRAMES:
        end = min(base + WINDOW_SIZE, TOTAL_FRAMES)
        print(f"Sender Window: [{base} to {end - 1}]")

        # Send all frames in the window that haven't been acknowledged
        for i in range(base, end):
            if not sender_window[i]:
                print(f"Sending Frame {i}...", end=' ')
                if random.random() > LOSS_PROBABILITY:
                    # Simulation of successful delivery to Receiver
                    receiver_window[i] = f"Frame {i} received"
                    print("Delivered.")
                else:
                    print("Lost.")
        # Process ACKs
        for i in range(base, end):
            # Check if the frame was received but the ACK hasn't been processed yet
            if receiver_window[i] is not None and not sender_window[i]:
                print(f"ACK received for Frame {i}")
                sender_window[i] = True
            elif receiver_window[i] is None:
                # Frame was lost, or its ACK was lost (retransmission needed)
                print(f"Waiting for ACK: Frame {i}")

        # Slide the window
        while base < TOTAL_FRAMES and sender_window[base]:
            base += 1
        print("-" * 40)
        time.sleep(DELAY)
    print("\nAll frames successfully transmitted and acknowledged.")
# Run the simulation
selective_repeat_protocol()
# Out:
# === Selective Repeat Sliding Window Protocol ===
#
# Sender Window: [0 to 3]
# Sending Frame 0... Lost.
# Sending Frame 1... Lost.
# Sending Frame 2... Lost.
# Sending Frame 3... Lost.
# Waiting for ACK: Frame 0
# Waiting for ACK: Frame 1
# Waiting for ACK: Frame 2
# Waiting for ACK: Frame 3
# ----------------------------------------
# Sender Window: [0 to 3]
# Sending Frame 0... Delivered.
# Sending Frame 1... Delivered.
# Sending Frame 2... Lost.
# Sending Frame 3... Lost.
# ACK received for Frame 0
# ACK received for Frame 1
# Waiting for ACK: Frame 2
# Waiting for ACK: Frame 3
# ----------------------------------------
# Sender Window: [2 to 5]
# Sending Frame 2... Delivered.
# Sending Frame 3... Delivered.
# Sending Frame 4... Delivered.
# Sending Frame 5... Lost.
# ACK received for Frame 2
# ACK received for Frame 3
# ACK received for Frame 4
# Waiting for ACK: Frame 5
# ----------------------------------------
# Sender Window: [5 to 8]
# Sending Frame 5... Delivered.
# Sending Frame 6... Delivered.
# Sending Frame 7... Delivered.
# Sending Frame 8... Lost.
# ACK received for Frame 5
# ACK received for Frame 6
# ACK received for Frame 7
# Waiting for ACK: Frame 8
# ----------------------------------------
# Sender Window: [8 to 9]
# Sending Frame 8... Lost.
# Sending Frame 9... Lost.
# Waiting for ACK: Frame 8
# Waiting for ACK: Frame 9
# ----------------------------------------
# Sender Window: [8 to 9]
# Sending Frame 8... Lost.
# Sending Frame 9... Delivered.
# Waiting for ACK: Frame 8
# ACK received for Frame 9
# ----------------------------------------
# Sender Window: [8 to 9]
# Sending Frame 8... Delivered.
# ACK received for Frame 8
# ----------------------------------------
#
# All frames successfully transmitted and acknowledged.

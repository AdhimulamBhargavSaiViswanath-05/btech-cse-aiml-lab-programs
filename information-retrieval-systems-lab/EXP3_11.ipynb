# %%
import os

def split_text(input_string):
    result = []
    word = ''
    for char in input_string:
        if char in (' ', '\t', '\n'):
            if word:
                result.append(word)
                word = ''
        else:
            word += char
    if word:
        result.append(word)
    return result



def remove_punctuation(words):
    punctuation_marks = ['.', ',', '!', '?', ';', ':', '"', "'", '(', ')',
                         '[', ']', '{', '}', '-', '_', '/', '\\', '`', '~',
                         '@', '#', '$', '%', '^', '&', '*', '=', '+', '<',
                         '>', '|']
    cleaned_words = []
    for word in words:
        clean_word = ''
        for char in word:
            if char not in punctuation_marks:
                clean_word += char
        if clean_word:
            cleaned_words.append(clean_word)
    return cleaned_words



# ===== Step 4: Manual lowercase =====
def manual_lowercase(word):
    char_map = {
        'A': 'a', 'B': 'b', 'C': 'c', 'D': 'd', 'E': 'e', 'F': 'f', 'G': 'g', 'H': 'h', 'I': 'i',
        'J': 'j', 'K': 'k', 'L': 'l', 'M': 'm', 'N': 'n', 'O': 'o', 'P': 'p', 'Q': 'q', 'R': 'r',
        'S': 's', 'T': 't', 'U': 'u', 'V': 'v', 'W': 'w', 'X': 'x', 'Y': 'y', 'Z': 'z'
    }
    result = ''
    for char in word:
        if char in char_map:
            result += char_map[char]
        else:
            result += char
    return result


def lowercase_words(word_list):
    result = []
    for word in word_list:
        result.append(manual_lowercase(word))
    return result



# ===== Step 5: Manual length function =====
def get_length(word):
    count = 0
    for _ in word:
        count += 1
    return count


# ===== Step 6: Remove stop words =====
stop_words = {
    "is", "a", "the", "for", "this", "an", "and", "in", "of", "on",
    "to", "its", "by", "has", "how", "we", "it", "with", "due", "since", "over", "from"
}


def remove_stop_words(word_list, stop_words):
    result = []
    for word in word_list:
        if word not in stop_words:
            result.append(word)
    return result



# ===== Step 7: Manual suffix checker =====
def ends_with(word, suffix):
    if len(word) < len(suffix):
        return False
    for i in range(1, len(suffix) + 1):
        if word[-i] != suffix[-i]:
            return False
    return True


# ===== Step 8: Protected words =====
protected = {
    # From your original
    "universe", "university", "police", "policy",
    "analysis", "analyst", "history", "historic",

    # Nouns ending with 'ing' that aren't verbs
    "spring", "king", "thing", "ceiling", "building", "morning", "evening",

    # Words that look like past tense but aren't meant to stem
    "composed", "supposed", "exposed", "proposed",

    # Words that look like continuous tense but are fixed nouns/adjectives
    "routing", "housing", "painting", "booking",

    # Prevent chopping in 'bringing' irregular case
    "bringing",

    # Other common over-stemming traps
    "news", "species", "series", "means", "physics", "mathematics",
    "economics", "ethics", "politics", "practice", "justice", "notice",
    "service", "advice", "basis", "crisis", "thesis", "oasis",
    "catalyst", "specialist", "specific", "traffic", "arctic",
    "logic", "magic"
}


# ===== Step 9: Irregular verbs dictionary =====
irregular_verbs = {
    "go": {"past": ["went"], "past_participle": ["gone"]},
    "buy": {"past": ["bought"], "past_participle": ["bought"]},
    "bring": {"past": ["brought"], "past_participle": ["brought"]},
    "run": {"past": ["ran"], "past_participle": ["run"]},
    "begin": {"past": ["began"], "past_participle": ["begun"]},
    "drink": {"past": ["drank"], "past_participle": ["drunk"]},
    "eat": {"past": ["ate"], "past_participle": ["eaten"]},
    "give": {"past": ["gave"], "past_participle": ["given"]},
    "take": {"past": ["took"], "past_participle": ["taken"]},
    "write": {"past": ["wrote"], "past_participle": ["written"]},
    "see": {"past": ["saw"], "past_participle": ["seen"]},
    "do": {"past": ["did"], "past_participle": ["done"]},
    "have": {"past": ["had"], "past_participle": ["had"]},
    "make": {"past": ["made"], "past_participle": ["made"]},
    "say": {"past": ["said"], "past_participle": ["said"]},
    "find": {"past": ["found"], "past_participle": ["found"]},
    "think": {"past": ["thought"], "past_participle": ["thought"]},
    "keep": {"past": ["kept"], "past_participle": ["kept"]},
    "feel": {"past": ["felt"], "past_participle": ["felt"]},
    "leave": {"past": ["left"], "past_participle": ["left"]},
    "meet": {"past": ["met"], "past_participle": ["met"]},
    "stand": {"past": ["stood"], "past_participle": ["stood"]},
    "sit": {"past": ["sat"], "past_participle": ["sat"]},
    "speak": {"past": ["spoke"], "past_participle": ["spoken"]},
    "understand": {"past": ["understood"], "past_participle": ["understood"]},
    "win": {"past": ["won"], "past_participle": ["won"]},
    "lose": {"past": ["lost"], "past_participle": ["lost"]},
    "build": {"past": ["built"], "past_participle": ["built"]},
    "pay": {"past": ["paid"], "past_participle": ["paid"]},
    "send": {"past": ["sent"], "past_participle": ["sent"]},
    "sell": {"past": ["sold"], "past_participle": ["sold"]},
    "catch": {"past": ["caught"], "past_participle": ["caught"]},
    "fight": {"past": ["fought"], "past_participle": ["fought"]},
    "teach": {"past": ["taught"], "past_participle": ["taught"]},
    "hold": {"past": ["held"], "past_participle": ["held"]},
    "hear": {"past": ["heard"], "past_participle": ["heard"]},
    "show": {"past": ["showed"], "past_participle": ["shown"]}
}


# ===== Step 10: Tense detection =====
def detect_tense(word):
    w = word.lower()
    for base, forms in irregular_verbs.items():
        if w in forms["past"]:
            return "Past Simple (irregular)"
        if w in forms["past_participle"]:
            return "Past Participle (irregular)"
        if w == base:
            return "Base Form / Present Simple"
    if ends_with(w, "ing") and len(w) > 4:
        return "Present Participle / Continuous"
    if ends_with(w, "ed") and len(w) > 3:
        return "Past Simple or Past Participle (regular)"
    if (ends_with(w, "s") or ends_with(w, "es")) and len(w) > 2:
        return "Present Simple (3rd person singular)"
    return "Base Form / Present Simple"


# ===== Step 11: Manual stemmer =====
def manual_stem(word):
    w = word.lower()
    if w in protected:
        return w
    for base, forms in irregular_verbs.items():
        if w in forms["past"] or w in forms["past_participle"]:
            return base
    length = len(w)
    if ends_with(w, "ies") and length > 3:
        w = w[:-3] + "y"
    elif ends_with(w, "es") and not ends_with(w, "ses") and not ends_with(w, "xes"):
        w = w[:-2]
    elif ends_with(w, "s") and length > 3:
        w = w[:-1]
    if ends_with(w, "ied") and length > 4:
        w = w[:-3] + "y"
    elif ends_with(w, "eed") and length > 3:
        w = w[:-1]
    elif ends_with(w, "ed") and length > 3:
        w = w[:-2]
        if not ends_with(w, "e"):
            w += "e"
    if ends_with(w, "ing") and len(w) > 4:
        w = w[:-3]
        if len(w) > 2 and w[-1] == w[-2]:
            w = w[:-1]
        if not ends_with(w, "e") and w not in protected:
            w += "e"
    if ends_with(w, "tion"):
        w = w[:-4] + "te"
    elif ends_with(w, "sion"):
        w = w[:-4] + "se"
    elif ends_with(w, "ment") or ends_with(w, "ness") or ends_with(w, "less"):
        w = w[:-4]
    elif ends_with(w, "able") or ends_with(w, "ible"):
        w = w[:-4]
    elif ends_with(w, "al") and len(w) > 4:
        w = w[:-2]
    elif ends_with(w, "er") and len(w) > 4:
        w = w[:-2]
    elif ends_with(w, "ly") and len(w) > 3:
        w = w[:-2]
    elif ends_with(w, "ous") and len(w) > 4:
        w = w[:-3]
    elif ends_with(w, "ive") and len(w) > 4:
        w = w[:-3]
    elif ends_with(w, "."):
        w = w[:-1]
    return w


# ===== Step 12: Apply stemming to full document =====
def apply_stemming(word_list):
    result = []
    for word in word_list:
        result.append((manual_stem(word)))
    return result








# Step 5: Inverted Index with Frequency
def build_inverted_index_with_frequency(documents):
    index = {}  # Dictionary to hold word: {doc_id: frequency, ...}
    for doc_id, doc in enumerate(documents, start=1):
        for word in doc:
            if word not in index:
                index[word] = {}
            if doc_id not in index[word]:
                index[word][doc_id] = 0
            index[word][doc_id] += 1
    return index

# Main Execution

# Path to your folder containing the 50 documents
folder_path = r"C:\Users\DELL\OneDrive\Documents\IRS LAB\documents"

all_documents = []

for i in range(1, 51):  # Loop over all 50 documents
    filename = f"doc{i}.txt"
    filepath = os.path.join(folder_path, filename)
    
    with open(filepath, 'r', encoding='utf-8') as f:
        data = f.read()
    
    # Preprocessing steps
    split_words = split_text(data)
    lowered = lowercase_words(split_words)
    no_stops = remove_stop_words(lowered, stop_words)
    stemmed = apply_stemming(no_stops)
    
    all_documents += [stemmed]

# Build the inverted index with frequencies
inverted_index = build_inverted_index_with_frequency(all_documents)

# Display inverted index
def display_inverted_index(inverted_index):
    print("\n=== Inverted Index ===\n")
    print(f"{'WORD':<20} {'DOCUMENT FREQUENCIES':<100} {'TOTAL':>5}")
    print("-" * 140)

    for word in sorted(inverted_index):
        doc_freqs = inverted_index[word]
        total = sum(doc_freqs.values())

        # Build document frequency list using 'Doc X: Y' format
        doc_freq_list = []
        for doc in doc_freqs:
            entry = "Doc " + str(doc) + ": " + str(doc_freqs[doc])
            doc_freq_list += [entry] 

        # Manually wrap the doc frequencies into lines of max 100 characters
        max_width = 100
        wrapped_lines = []
        current_line = ""

        for entry in doc_freq_list:
            new_line = current_line + (", " if current_line else "") + entry
            if len(new_line) > max_width:
                wrapped_lines += [current_line]
                current_line = entry
            else:
                current_line = new_line
        if current_line:
            wrapped_lines += [current_line]

        # Print first line with the word
        print(f"{word:<20} {wrapped_lines[0]:<100} {total:>5}")

        # Print remaining lines indented
        for line in wrapped_lines[1:]:
            print(f"{'':<20} {line:<100}")

# To count total vocabulary size
vocab_count = 0
for word in inverted_index:
    vocab_count += 1

print("\nTotal Vocabulary Size:", vocab_count)

display_inverted_index(inverted_index)
print("\n")
# Out:
# Total Vocabulary Size: 1111
#
# === Inverted Index ===
#
# WORD                 DOCUMENT FREQUENCIES                                                                                 TOTAL
# --------------------------------------------------------------------------------------------------------------------------------------------
#                      Doc 2: 1, Doc 9: 1, Doc 15: 1, Doc 39: 1                                                                 4
# ability              Doc 4: 1, Doc 20: 1, Doc 22: 1, Doc 23: 1, Doc 26: 1, Doc 35: 1, Doc 41: 1, Doc 42: 1, Doc 46: 1        11
#                      Doc 49: 1, Doc 50: 1
# able                 Doc 6: 1, Doc 38: 1                                                                                      2
# about                Doc 4: 1, Doc 13: 1, Doc 14: 1, Doc 30: 1, Doc 32: 1, Doc 34: 1, Doc 35: 1, Doc 45: 1, Doc 50: 1         9
# above                Doc 1: 1, Doc 2: 1, Doc 7: 1, Doc 9: 1, Doc 10: 1, Doc 11: 1, Doc 15: 1, Doc 19: 1, Doc 24: 1           17
#                      Doc 26: 1, Doc 28: 2, Doc 29: 1, Doc 31: 2, Doc 35: 1, Doc 45: 1
# accept               Doc 4: 1, Doc 22: 1, Doc 40: 1, Doc 42: 1                                                                4
# accorde              Doc 3: 1, Doc 8: 1, Doc 19: 2, Doc 26: 1, Doc 27: 1, Doc 31: 1, Doc 39: 1, Doc 42: 2, Doc 50: 1         11
# according            Doc 4: 2                                                                                                 2
# account              Doc 22: 1, Doc 26: 1, Doc 31: 1, Doc 34: 1, Doc 37: 1, Doc 38: 2                                         7
# acros                Doc 6: 1, Doc 7: 1, Doc 10: 1, Doc 11: 1, Doc 29: 1, Doc 34: 1, Doc 37: 1, Doc 39: 1, Doc 41: 1         10
#                      Doc 50: 1
# across               Doc 26: 1, Doc 44: 1, Doc 47: 1                                                                          3
# act                  Doc 2: 1, Doc 5: 1, Doc 11: 1, Doc 20: 1, Doc 21: 1, Doc 23: 1, Doc 30: 1, Doc 45: 1, Doc 47: 1         10
#                      Doc 50: 1
# acte                 Doc 6: 1, Doc 15: 1, Doc 16: 1, Doc 38: 1, Doc 41: 1, Doc 49: 1, Doc 50: 1                               7
# action               Doc 8: 1, Doc 12: 1, Doc 19: 1                                                                           3
# activity             Doc 1: 2, Doc 7: 1, Doc 10: 1, Doc 21: 1, Doc 24: 1, Doc 29: 1, Doc 33: 1, Doc 34: 1, Doc 50: 2         11
# actual               Doc 3: 1, Doc 6: 1, Doc 9: 1, Doc 12: 1, Doc 16: 1, Doc 17: 1, Doc 20: 1, Doc 26: 1, Doc 31: 1          10
#                      Doc 36: 1
# actually             Doc 8: 1, Doc 28: 1                                                                                      2
# add                  Doc 3: 1, Doc 5: 1, Doc 7: 1, Doc 14: 1, Doc 22: 1, Doc 25: 1, Doc 33: 1, Doc 45: 1, Doc 49: 1          10
#                      Doc 50: 1
# addres               Doc 1: 1, Doc 19: 1, Doc 22: 1, Doc 34: 1, Doc 47: 1, Doc 48: 1, Doc 49: 1                               7
# address              Doc 40: 1                                                                                                1
# administrate         Doc 11: 1, Doc 22: 1, Doc 26: 1, Doc 41: 1                                                               4

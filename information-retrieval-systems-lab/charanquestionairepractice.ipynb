# %%
a=11
for i in range(1,11):
    result = a*i
    print(f"{a}*{i}={result}")
# Out:
# 11*1=11
# 11*2=22
# 11*3=33
# 11*4=44
# 11*5=55
# 11*6=66
# 11*7=77
# 11*8=88
# 11*9=99
# 11*10=110

# %%
a = int(input("Enter a value:"))

for i in range(1,11):
    result = a*i
    print(f"{a}*{i}={result}")
# Out:
# Enter a value: 11
# 11*1=11
# 11*2=22
# 11*3=33
# 11*4=44
# 11*5=55
# 11*6=66
# 11*7=77
# 11*8=88
# 11*9=99
# 11*10=110
